# %% [markdown]
# <a href="https://colab.research.google.com/github/Ambrgna/CS-5530-Assignment-2/blob/main/used_cars/src/used_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read Raw Data

# %%
url = 'https://raw.githubusercontent.com/Ambrgna/CS-5530-Assignment-2/refs/heads/main/used_cars/data_raw/raw_used_cars_data.csv'
df = pd.read_csv(url)
df.head(10)
# Out:
#    Unnamed: 0                                 Name    Location  Year  \
# 0           1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                         Honda Jazz V     Chennai  2011
# 2           3                    Maruti Ertiga VDI     Chennai  2012
# 3           4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6               Nissan Micra Diesel XV      Jaipur  2013
# 5           7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 6           8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 7           9       Tata Indica Vista Quadrajet LS     Chennai  2012
# 8          10                     Maruti Ciaz Zeta       Kochi  2018
# 9          11          Honda City 1.5 V AT Sunroof     Kolkata  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
# 5              36000    Diesel    Automatic      First  11.36 kmpl  2755 CC
# 6              64430    Diesel       Manual      First  20.54 kmpl  1598 CC
# 7              65932    Diesel       Manual     Second   22.3 kmpl  1248 CC
# 8              25692    Petrol       Manual      First  21.56 kmpl  1462 CC
# 9              60000    Petrol    Automatic      First   16.8 kmpl  1497 CC
#
#         Power  Seats   New_Price  Price
# 0   126.2 bhp    5.0         NaN  12.50
# 1    88.7 bhp    5.0   8.61 Lakh   4.50
# 2   88.76 bhp    7.0         NaN   6.00
# 3   140.8 bhp    5.0         NaN  17.74
# 4    63.1 bhp    5.0         NaN   3.50
# 5   171.5 bhp    8.0     21 Lakh  17.50
# 6   103.6 bhp    5.0         NaN   5.20
# 7      74 bhp    5.0         NaN   1.95
# 8  103.25 bhp    5.0  10.65 Lakh   9.95
# 9   116.3 bhp    5.0         NaN   4.49

# %% [markdown]
# Look for the missing values

# %%
df.isna().sum()/len(df)*100
# Out:
# Unnamed: 0            0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.034206
# Engine                0.615700
# Power                 0.615700
# Seats                 0.649906
# New_Price            86.061228
# Price                 0.000000
# dtype: float64

# %% [markdown]
# impute or drop

# %%
df_impute = df.copy()
df_impute.dropna(thresh=0.8*len(df_impute),axis=1,inplace=True)
df_impute.dropna(axis=0,inplace=True)
df_impute.isna().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# The New_Price column has more than 80% missing values, so I dropped the entire column. With that much missing data, imputing would not be meaningful and the column would not contribute reliable information.
#
# The missing values in Mileage, Engine, Power, and Seats are each less than 1% of the dataset. Because so few rows are affected, dropping these rows does not significantly reduce the dataset or impact the analysis. Imputing such a small number of values is unnecessary.

# %% [markdown]
# Remove the units

# %%
df_numeric = df_impute.copy()
mileage_split  = df_numeric["Mileage"].str.split(" ", expand=True)
engine_split  = df_numeric["Engine"].str.split(" ", expand=True)
power_split  = df_numeric["Power"].str.split(" ", expand=True)
print(mileage_split [1].unique())
print(engine_split [1].unique())
print(power_split [1].unique())

df_numeric["Mileage"] = (
    mileage_split[0].astype(float)
    .where(mileage_split[1] == "kmpl", mileage_split[0].astype(float) * 0.54)
)
df_numeric["Engine"] = engine_split [0].astype(float)
df_numeric["Power"] = power_split [0].astype(float)
df_numeric.dtypes
# Out:
# ['kmpl' 'km/kg']
# ['CC']
# ['bhp']
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %% [markdown]
# Numerical one hot encoded

# %%
df_encoded = pd.get_dummies(df_numeric, columns=["Fuel_Type","Transmission"],dtype=int)
df_encoded.head(10)
# Out:
#    Unnamed: 0                                 Name    Location  Year  \
# 0           1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                         Honda Jazz V     Chennai  2011
# 2           3                    Maruti Ertiga VDI     Chennai  2012
# 3           4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6               Nissan Micra Diesel XV      Jaipur  2013
# 5           7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 6           8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 7           9       Tata Indica Vista Quadrajet LS     Chennai  2012
# 8          10                     Maruti Ciaz Zeta       Kochi  2018
# 9          11          Honda City 1.5 V AT Sunroof     Kolkata  2012
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First    19.67  1582.0  126.20    5.0  12.50
# 1              46000      First     7.02  1199.0   88.70    5.0   4.50
# 2              87000      First    20.77  1248.0   88.76    7.0   6.00
# 3              40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4              86999      First    23.08  1461.0   63.10    5.0   3.50
# 5              36000      First    11.36  2755.0  171.50    8.0  17.50
# 6              64430      First    20.54  1598.0  103.60    5.0   5.20
# 7              65932     Second    22.30  1248.0   74.00    5.0   1.95
# 8              25692      First    21.56  1462.0  103.25    5.0   9.95
# 9              60000      First    16.80  1497.0  116.30    5.0   4.49
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 0                 1                 0                       0
# 1                 0                 1                       0
# 2                 1                 0                       0
# 3                 1                 0                       1
# 4                 1                 0                       0
# 5                 1                 0                       1
# 6                 1                 0                       0
# 7                 1                 0                       0
# 8                 0                 1                       0
# 9                 0                 1                       1
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    0
# 4                    1
# 5                    0
# 6                    1
# 7                    1
# 8                    1
# 9                    0

# %% [markdown]
# Create one more feature (Yearly_Millage)

# %%
from datetime import datetime

df_feature = df_encoded.copy()

current_year = datetime.now().year

yearly_millage = (df_feature['Kilometers_Driven'] / (current_year-df_feature["Year"])).round(2)

index = df_feature.columns.get_loc("Kilometers_Driven")
df_feature.insert(index + 1, "Yearly_Millage", yearly_millage)
df_feature
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven  Yearly_Millage Owner_Type  Mileage  Engine   Power  \
# 0                 41000         4100.00      First    19.67  1582.0  126.20
# 1                 46000         3285.71      First     7.02  1199.0   88.70
# 2                 87000         6692.31      First    20.77  1248.0   88.76
# 3                 40670         3389.17     Second    15.20  1968.0  140.80
# 4                 86999         7249.92      First    23.08  1461.0   63.10
# ...                 ...             ...        ...      ...     ...     ...
# 5842              27365         2487.73      First    28.40  1248.0   74.00
# 5843             100000        10000.00      First    24.40  1120.0   71.00
# 5844              55000         4230.77     Second    14.00  2498.0  112.00
# 5845              46000         3833.33      First    18.90   998.0   67.10
# 5846              47000         3357.14      First    25.44   936.0   57.60
#
#       Seats  Price  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0       5.0  12.50                 1                 0
# 1       5.0   4.50                 0                 1
# 2       7.0   6.00                 1                 0
# 3       5.0  17.74                 1                 0
# 4       5.0   3.50                 1                 0
# ...     ...    ...               ...               ...
# 5842    5.0   4.75                 1                 0
# 5843    5.0   4.00                 1                 0
# 5844    8.0   2.90                 1                 0
# 5845    5.0   2.65                 0                 1
# 5846    5.0   2.50                 1                 0
#
#       Transmission_Automatic  Transmission_Manual
# 0                          0                    1
# 1                          0                    1
# 2                          0                    1
# 3                          1                    0
# 4                          0                    1
# ...                      ...                  ...
# 5842                       0                    1
# 5843                       0                    1
# 5844                       0                    1
# 5845                       0                    1
# 5846                       0                    1
#
# [5807 rows x 16 columns]

# %% [markdown]
# Select

# %%
df_selected = df_feature[["Name", "Year", "Fuel_Type_Petrol", "Price"]]
df_selected
# Out:
#                                   Name  Year  Fuel_Type_Petrol  Price
# 0     Hyundai Creta 1.6 CRDi SX Option  2015                 0  12.50
# 1                         Honda Jazz V  2011                 1   4.50
# 2                    Maruti Ertiga VDI  2012                 0   6.00
# 3      Audi A4 New 2.0 TDI Multitronic  2013                 0  17.74
# 4               Nissan Micra Diesel XV  2013                 0   3.50
# ...                                ...   ...               ...    ...
# 5842                  Maruti Swift VDI  2014                 0   4.75
# 5843          Hyundai Xcent 1.1 CRDi S  2015                 0   4.00
# 5844             Mahindra Xylo D4 BSIV  2012                 0   2.90
# 5845                Maruti Wagon R VXI  2013                 1   2.65
# 5846             Chevrolet Beat Diesel  2011                 0   2.50
#
# [5807 rows x 4 columns]

# %% [markdown]
# filter

# %%
df_filter = df_selected[df_selected["Year"] > 2010]
df_filter
# Out:
#                                   Name  Year  Fuel_Type_Petrol  Price
# 0     Hyundai Creta 1.6 CRDi SX Option  2015                 0  12.50
# 1                         Honda Jazz V  2011                 1   4.50
# 2                    Maruti Ertiga VDI  2012                 0   6.00
# 3      Audi A4 New 2.0 TDI Multitronic  2013                 0  17.74
# 4               Nissan Micra Diesel XV  2013                 0   3.50
# ...                                ...   ...               ...    ...
# 5842                  Maruti Swift VDI  2014                 0   4.75
# 5843          Hyundai Xcent 1.1 CRDi S  2015                 0   4.00
# 5844             Mahindra Xylo D4 BSIV  2012                 0   2.90
# 5845                Maruti Wagon R VXI  2013                 1   2.65
# 5846             Chevrolet Beat Diesel  2011                 0   2.50
#
# [4853 rows x 4 columns]

# %% [markdown]
# rename

# %%
df_renamed = df_feature.copy()
df_renamed.rename(columns={"Kilometers_Driven": "Odometer"}, inplace=True)
df_renamed
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Odometer  Yearly_Millage Owner_Type  Mileage  Engine   Power  Seats  \
# 0        41000         4100.00      First    19.67  1582.0  126.20    5.0
# 1        46000         3285.71      First     7.02  1199.0   88.70    5.0
# 2        87000         6692.31      First    20.77  1248.0   88.76    7.0
# 3        40670         3389.17     Second    15.20  1968.0  140.80    5.0
# 4        86999         7249.92      First    23.08  1461.0   63.10    5.0
# ...        ...             ...        ...      ...     ...     ...    ...
# 5842     27365         2487.73      First    28.40  1248.0   74.00    5.0
# 5843    100000        10000.00      First    24.40  1120.0   71.00    5.0
# 5844     55000         4230.77     Second    14.00  2498.0  112.00    8.0
# 5845     46000         3833.33      First    18.90   998.0   67.10    5.0
# 5846     47000         3357.14      First    25.44   936.0   57.60    5.0
#
#       Price  Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 0     12.50                 1                 0                       0
# 1      4.50                 0                 1                       0
# 2      6.00                 1                 0                       0
# 3     17.74                 1                 0                       1
# 4      3.50                 1                 0                       0
# ...     ...               ...               ...                     ...
# 5842   4.75                 1                 0                       0
# 5843   4.00                 1                 0                       0
# 5844   2.90                 1                 0                       0
# 5845   2.65                 0                 1                       0
# 5846   2.50                 1                 0                       0
#
#       Transmission_Manual
# 0                       1
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# ...                   ...
# 5842                    1
# 5843                    1
# 5844                    1
# 5845                    1
# 5846                    1
#
# [5807 rows x 16 columns]

# %% [markdown]
# mutate

# %%
df_mutated = df_encoded.copy()
df_mutated["Kilometers_Driven"] = (df["Kilometers_Driven"] * 0.621371).round(2)

df_mutated.rename(columns={"Kilometers_Driven": "Miles_Driven"}, inplace=True)

df_mutated
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Miles_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0         25476.21      First    19.67  1582.0  126.20    5.0  12.50
# 1         28583.07      First     7.02  1199.0   88.70    5.0   4.50
# 2         54059.28      First    20.77  1248.0   88.76    7.0   6.00
# 3         25271.16     Second    15.20  1968.0  140.80    5.0  17.74
# 4         54058.66      First    23.08  1461.0   63.10    5.0   3.50
# ...            ...        ...      ...     ...     ...    ...    ...
# 5842      17003.82      First    28.40  1248.0   74.00    5.0   4.75
# 5843      62137.10      First    24.40  1120.0   71.00    5.0   4.00
# 5844      34175.40     Second    14.00  2498.0  112.00    8.0   2.90
# 5845      28583.07      First    18.90   998.0   67.10    5.0   2.65
# 5846      29204.44      First    25.44   936.0   57.60    5.0   2.50
#
#       Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 0                    1                 0                       0
# 1                    0                 1                       0
# 2                    1                 0                       0
# 3                    1                 0                       1
# 4                    1                 0                       0
# ...                ...               ...                     ...
# 5842                 1                 0                       0
# 5843                 1                 0                       0
# 5844                 1                 0                       0
# 5845                 0                 1                       0
# 5846                 1                 0                       0
#
#       Transmission_Manual
# 0                       1
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# ...                   ...
# 5842                    1
# 5843                    1
# 5844                    1
# 5845                    1
# 5846                    1
#
# [5807 rows x 15 columns]

# %% [markdown]
# arrange

# %%
df_sorted = df_feature.sort_values(by="Year",ascending=False)
df_sorted
# Out:
#       Unnamed: 0                                        Name    Location  \
# 1042        1077               Maruti Vitara Brezza ZDi Plus       Kochi
# 5284        5434            Honda WR-V Edge Edition i-VTEC S       Kochi
# 2639        2728                     Maruti Baleno Alpha CVT       Kochi
# 5608        5769                  Tata Tiago 1.2 Revotron XZ  Coimbatore
# 492          512  Hyundai Creta 1.6 SX Plus Dual Tone Petrol       Kochi
# ...          ...                                         ...         ...
# 1185        1224                               Maruti Zen VX      Jaipur
# 1791        1845                          Honda City 1.3 EXI        Pune
# 3630        3749           Mercedes-Benz E-Class 250 D W 210      Mumbai
# 3039        3138                              Maruti Zen LXI      Jaipur
# 5558        5716                               Maruti Zen LX      Jaipur
#
#       Year  Kilometers_Driven  Yearly_Millage Owner_Type  Mileage  Engine  \
# 1042  2019              34688         5781.33      First    24.30  1248.0
# 5284  2019              13913         2318.83      First    17.50  1199.0
# 2639  2019              13574         2262.33      First    21.40  1197.0
# 5608  2019              20712         3452.00      First    23.84  1199.0
# 492   2019               8587         1431.17      First    15.29  1591.0
# ...    ...                ...             ...        ...      ...     ...
# 1185  1999              70000         2692.31     Second    17.30   993.0
# 1791  1999             140000         5384.62      First    13.00  1343.0
# 3630  1998              55300         2048.15      First    10.00  1796.0
# 3039  1998              95150         3524.07      Third    17.30   993.0
# 5558  1998              95150         3524.07      Third    17.30   993.0
#
#       Power  Seats  Price  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 1042   88.5    5.0  10.49                 1                 0
# 5284   88.7    5.0   8.20                 0                 1
# 2639   83.1    5.0   9.51                 0                 1
# 5608   84.0    5.0   6.94                 0                 1
# 492   121.3    5.0  13.56                 0                 1
# ...     ...    ...    ...               ...               ...
# 1185   60.0    5.0   0.77                 0                 1
# 1791   90.0    5.0   0.90                 0                 1
# 3630  157.7    5.0   3.90                 1                 0
# 3039   60.0    5.0   0.45                 0                 1
# 5558   60.0    5.0   0.53                 0                 1
#
#       Transmission_Automatic  Transmission_Manual
# 1042                       0                    1
# 5284                       0                    1
# 2639                       1                    0
# 5608                       0                    1
# 492                        0                    1
# ...                      ...                  ...
# 1185                       0                    1
# 1791                       0                    1
# 3630                       1                    0
# 3039                       0                    1
# 5558                       0                    1
#
# [5807 rows x 16 columns]

# %% [markdown]
# summarize with group by operations

# %%
df_feature.groupby("Year")["Price"].mean()
# Out:
# Year
# 1998     1.626667
# 1999     0.835000
# 2000     1.175000
# 2001     0.975000
# 2002     1.273636
# 2003     1.697857
# 2004     2.012000
# 2005     2.290952
# 2006     3.673485
# 2007     3.448558
# 2008     3.640437
# 2009     5.276073
# 2010     5.500396
# 2011     6.833933
# 2012     7.448657
# 2013     8.830794
# 2014     9.739079
# 2015    11.344118
# 2016    11.775130
# 2017    13.848778
# 2018    15.884558
# 2019    19.603564
# Name: Price, dtype: float64
